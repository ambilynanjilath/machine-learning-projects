# %% [markdown]
# # Load the Data and Create DataFrame

# %%
import pandas as pd
df=pd.read_csv('/content/drug200.csv')
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  DrugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  DrugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# **Printing first 5 rows**

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %% [markdown]
# **Printing last 5 rows**

# %%
df.tail()
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX

# %% [markdown]
# **Printing the shape**

# %%
df.shape
# Out:
# (200, 6)

# %% [markdown]
# **Printing datatypes**

# %%
df.dtypes
# Out:
# Age              int64
# Sex             object
# BP              object
# Cholesterol     object
# Na_to_K        float64
# Drug            object
# dtype: object

# %% [markdown]
# **Printing the total missing value**

# %%
df.isna().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %% [markdown]
# **Print the column names**

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K', 'Drug'], dtype='object')

# %% [markdown]
# **Print the count of class**

# %%
a=df['Drug'].value_counts()
a
# Out:
# DrugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64

# %% [markdown]
# **Pie Chart of class distribution**

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
a.plot(kind='bar')
plt.xlabel('Class Labels')
plt.ylabel('Count')
plt.title('Class Distribution')
plt.show()

# %% [markdown]
# **Count of categorical columns and visual representation**

# %%
b=df['Sex'].value_counts()
b
# Out:
# M    104
# F     96
# Name: Sex, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(3,3))
plt.pie(b, labels=b.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Proportion of Sex')
plt.show()

# %%
c=df['BP'].value_counts()
c
# Out:
# HIGH      77
# LOW       64
# NORMAL    59
# Name: BP, dtype: int64

# %%
plt.figure(figsize=(3,3))
plt.pie(c, labels=c.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Proportion of BloodPressure Value')
plt.show()

# %%
d=df['Cholesterol'].value_counts()
d
# Out:
# HIGH      103
# NORMAL     97
# Name: Cholesterol, dtype: int64

# %%
plt.figure(figsize=(3,3))
plt.pie(d, labels=d.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Proportion of Cholesterol Values')
plt.show()

# %% [markdown]
# **Applied LabelEncoding to transform the categorical values**

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Sex']=lb.fit_transform(df['Sex'])
df['BP']=lb.fit_transform(df['BP'])
df['Cholesterol']=lb.fit_transform(df['Cholesterol'])

# %%
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   0            0   25.355  DrugY
# 1     47    1   1            0   13.093  drugC
# 2     47    1   1            0   10.114  drugC
# 3     28    0   2            0    7.798  drugX
# 4     61    0   1            0   18.043  DrugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   1            0   11.567  drugC
# 196   16    1   1            0   12.006  drugC
# 197   52    1   2            0    9.894  drugX
# 198   23    1   2            1   14.020  drugX
# 199   40    0   1            1   11.349  drugX
#
# [200 rows x 6 columns]

# %% [markdown]
# **Seperate x as input feature and y as class label**

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 0     23    0   0            0   25.355
# 1     47    1   1            0   13.093
# 2     47    1   1            0   10.114
# 3     28    0   2            0    7.798
# 4     61    0   1            0   18.043
# ..   ...  ...  ..          ...      ...
# 195   56    0   1            0   11.567
# 196   16    1   1            0   12.006
# 197   52    1   2            0    9.894
# 198   23    1   2            1   14.020
# 199   40    0   1            1   11.349
#
# [200 rows x 5 columns]

# %%
y
# Out:
# 0      DrugY
# 1      drugC
# 2      drugC
# 3      drugX
# 4      DrugY
#        ...
# 195    drugC
# 196    drugC
# 197    drugX
# 198    drugX
# 199    drugX
# Name: Drug, Length: 200, dtype: object

# %% [markdown]
# **Split the data into training and testing**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 169   20    0   0            0   11.262
# 97    56    0   0            0   25.395
# 31    74    1   0            0    9.567
# 12    43    1   1            0   15.376
# 35    46    1   2            1    7.285
# ..   ...  ...  ..          ...      ...
# 106   22    1   2            0   11.953
# 14    50    0   2            0   12.703
# 92    29    0   0            0   29.450
# 179   67    0   2            0   15.891
# 102   28    0   1            0   13.127
#
# [140 rows x 5 columns]

# %%
x_test
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 95    36    1   1            1   11.424
# 15    16    0   0            1   15.516
# 30    18    0   2            1    8.750
# 158   59    0   1            0   10.444
# 128   47    1   1            1   33.542
# 115   51    1   0            0   18.295
# 69    18    0   0            1   24.276
# 170   28    0   2            0   12.879
# 174   42    1   0            1   12.766
# 45    66    0   2            1    8.107
# 66    29    1   0            0   12.856
# 182   20    0   1            1   11.686
# 165   38    1   1            0   18.295
# 78    19    0   0            0   13.313
# 186   70    1   0            0    9.849
# 177   25    1   2            0   19.011
# 56    65    1   0            1   11.340
# 152   55    1   2            1    7.261
# 82    32    0   1            0    9.712
# 68    54    1   2            0   24.658
# 124   53    0   0            1   12.495
# 16    69    1   1            1   11.455
# ...

# %%
y_train
# Out:
# 169    drugA
# 97     DrugY
# 31     drugB
# 12     DrugY
# 35     drugX
#        ...
# 106    drugX
# 14     drugX
# 92     DrugY
# 179    DrugY
# 102    drugC
# Name: Drug, Length: 140, dtype: object

# %%
y_test
# Out:
# 95     drugX
# 15     DrugY
# 30     drugX
# 158    drugC
# 128    DrugY
# 115    DrugY
# 69     DrugY
# 170    drugX
# 174    drugA
# 45     drugX
# 66     drugA
# 182    drugX
# 165    DrugY
# 78     drugA
# 186    drugB
# 177    DrugY
# 56     drugB
# 152    drugX
# 82     drugC
# 68     DrugY
# 124    drugB
# 16     drugX
# 148    drugX
# 93     DrugY
# 65     DrugY
# 60     DrugY
# 84     drugC
# 67     drugX
# 125    DrugY
# 132    drugX
# 9      DrugY
# 18     drugC
# 55     drugC
# 75     DrugY
# 150    drugA
# 104    DrugY
# 135    drugX
# 137    drugA
# 164    DrugY
# 76     drugA
# 79     drugX
# 197    drugX
# 38     drugX
# 24     DrugY
# 122    DrugY
# 195    drugC
# 29     DrugY
# 19     DrugY
# 143    DrugY
# 86     drugX
# 114    drugX
# 173    DrugY
# 5      drugX
# 126    DrugY
# 117    drugX
# 73     DrugY
# 140    drugA
# 98     DrugY
# 172    DrugY
# 96     DrugY
# Name: Drug, dtype: object

# %% [markdown]
# **Applied MinMaxScalar for data Normalization**

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
scalar.fit(x_train)
x_train=scalar.transform(x_train)
x_test=scalar.transform(x_test)

# %%
x_train
# Out:
# array([[0.08474576, 0.        , 0.        , 0.        , 0.15010654],
#        [0.69491525, 0.        , 0.        , 0.        , 0.61340764],
#        [1.        , 1.        , 0.        , 0.        , 0.09454188],
#        [0.47457627, 1.        , 0.5       , 0.        , 0.28496968],
#        [0.52542373, 1.        , 1.        , 1.        , 0.01973447],
#        [0.77966102, 0.        , 0.        , 0.        , 0.61603016],
#        [0.59322034, 1.        , 1.        , 1.        , 0.29854122],
#        [0.83050847, 1.        , 0.        , 1.        , 0.46710375],
#        [0.79661017, 1.        , 1.        , 0.        , 0.32489756],
#        [0.6779661 , 0.        , 0.        , 0.        , 0.14076381],
#        [0.88135593, 1.        , 1.        , 1.        , 0.13817407],
#        [0.33898305, 1.        , 1.        , 1.        , 0.03809212],
#        [0.47457627, 1.        , 1.        , 1.        , 0.20245861],
#        [0.72881356, 0.        , 0.        , 1.        , 0.2476971 ],
# ...

# %%
x_test
# Out:
# array([[ 0.3559322 ,  1.        ,  0.5       ,  1.        ,  0.15541714],
#        [ 0.01694915,  0.        ,  0.        ,  1.        ,  0.28955909],
#        [ 0.05084746,  0.        ,  1.        ,  1.        ,  0.06775938],
#        [ 0.74576271,  0.        ,  0.5       ,  0.        ,  0.12329126],
#        [ 0.54237288,  1.        ,  0.5       ,  1.        ,  0.88047861],
#        [ 0.61016949,  1.        ,  0.        ,  0.        ,  0.38065891],
#        [ 0.05084746,  0.        ,  0.        ,  1.        ,  0.57672513],
#        [ 0.22033898,  0.        ,  1.        ,  0.        ,  0.20311424],
#        [ 0.45762712,  1.        ,  0.        ,  1.        ,  0.19940993],
#        [ 0.86440678,  0.        ,  1.        ,  1.        ,  0.04668087],
#        [ 0.23728814,  1.        ,  0.        ,  0.        ,  0.20236027],
#        [ 0.08474576,  0.        ,  0.5       ,  1.        ,  0.1640059 ],
#        [ 0.38983051,  1.        ,  0.5       ,  0.        ,  0.38065891],
# ...

# %% [markdown]
# # Model Creation

# %% [markdown]
# **Created model using DecisionTreeClassifier**

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy',splitter='best')
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['drugX', 'DrugY', 'drugX', 'drugC', 'DrugY', 'DrugY', 'DrugY',
#        'drugX', 'drugA', 'drugX', 'drugA', 'drugX', 'DrugY', 'drugA',
#        'drugB', 'DrugY', 'drugB', 'drugX', 'drugC', 'DrugY', 'drugB',
#        'drugX', 'drugX', 'DrugY', 'DrugY', 'DrugY', 'drugC', 'drugX',
#        'DrugY', 'drugX', 'DrugY', 'drugC', 'drugC', 'DrugY', 'drugA',
#        'DrugY', 'drugX', 'drugA', 'DrugY', 'drugA', 'drugX', 'drugX',
#        'drugX', 'DrugY', 'DrugY', 'drugC', 'DrugY', 'DrugY', 'DrugY',
#        'drugX', 'drugX', 'DrugY', 'drugX', 'DrugY', 'drugX', 'DrugY',
#        'drugA', 'DrugY', 'DrugY', 'DrugY'], dtype=object)

# %% [markdown]
# **Decision Tree Visualization**

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10,8))
plot_tree(model, filled=True, feature_names=x.columns, class_names=y.unique())
plt.title('Decision Tree Visualization for Drug Classification')
plt.show()

# %% [markdown]
# **Feature Importance Bar Plot**

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
feature_importance = model.feature_importances_
sns.barplot(x=feature_importance, y=x.columns)
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('Decision Tree Feature Importance')
plt.show()

# %% [markdown]
# # Performance Evaluation

# %% [markdown]
# **Confusion Matrix Visualization**

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='YlGnBu', xticklabels=y.unique(), yticklabels=y.unique())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print("Accuracy Score",accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score 1.0

# %%
print("Classification Report")
print(classification_report(y_test,y_pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#        DrugY       1.00      1.00      1.00        26
#        drugA       1.00      1.00      1.00         7
#        drugB       1.00      1.00      1.00         3
#        drugC       1.00      1.00      1.00         6
#        drugX       1.00      1.00      1.00        18
#
#     accuracy                           1.00        60
#    macro avg       1.00      1.00      1.00        60
# weighted avg       1.00      1.00      1.00        60

# %%
# !sudo apt-get update
# !sudo apt-get install texlive-xetex
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [731 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [108 kB]
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [734 kB]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 1,802 kB in 3s (588 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# !jupyter nbconvert --to pdf '/content/Drug_Classification_DecisionTreeClassification.ipynb'
# Out:
# [NbConvertApp] Converting notebook /content/Drug_Classification_DecisionTreeClassification.ipynb to pdf
# [NbConvertApp] Support files will be in Drug_Classification_DecisionTreeClassification_files/
# [NbConvertApp] Making directory ./Drug_Classification_DecisionTreeClassification_files
# [NbConvertApp] Making directory ./Drug_Classification_DecisionTreeClassification_files
# [NbConvertApp] Making directory ./Drug_Classification_DecisionTreeClassification_files
# [NbConvertApp] Making directory ./Drug_Classification_DecisionTreeClassification_files
# [NbConvertApp] Making directory ./Drug_Classification_DecisionTreeClassification_files
# [NbConvertApp] Making directory ./Drug_Classification_DecisionTreeClassification_files
# [NbConvertApp] Making directory ./Drug_Classification_DecisionTreeClassification_files
# [NbConvertApp] Writing 68535 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# ...
